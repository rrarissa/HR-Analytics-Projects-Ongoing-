# %% [markdown]
# # HR Analytics Project

# %% [markdown]
# ***HR analytics is the process of collecting and analyzing Human Resource (HR) data in order to improve an organization’s workforce performance. The process can also be referred to as talent analytics, people analytics, or even workforce analytics.***

# %% [markdown]
# ***In order to remain successful and competitive, all businesses and organizations must be capable of changing, growing, and evolving to meet the new challenges and realities that they face. This is true for every department within an organization, including human resources. HR analytics can be leveraged in order to create an iterative framework for making these necessary refinements as they become apparent.***

# %% [markdown]
# ![attracting-and-retaining-top-talent-why-is-it-so-difficult.jpg](attachment:attracting-and-retaining-top-talent-why-is-it-so-difficult.jpg)

# %% [markdown]
# # 1. Introduction of the Dataset

# %% [markdown]
# ### IBM employee attrition data. Each row is personal and attrition information of an employee.

# %% [markdown]
# Dataset download:
# https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset

# %% [markdown]
# 1. Age: 18 to 60 years old
# 2. Attrition: Whether employees are still with the company or whether they’ve gone to work somewhere else.
# 3. BusinessTravel: Travel_Rarely, Travel_Frequently, Non-Travel.
# 4. Daily Rate
# 5. Department: Research & Development, Sales, Human Resources.
# 6. DistanceFromHome: Distance between the company and their home in miles.
# 7. Education: 1 'Below College' 2 'College' 3 'Bachelor' 4 'Master' 5 'Doctor'.
# 8. EducationField: Life Sciences， Medical， Marketing，Technical Degree，Other.
# 9. Employee Count
# 10. Employee Number
# 11. EnvironmentSatisfaction: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'.
# 12. Gender
# 13. Hourly Rate
# 14. JobInvolvement: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'.
# 15. Job Level
# 16. JobRole: Sales Executive，Research Science, Laboratory Tec, Manufacturing, Healthcare Rep, etc
# 17. JobSatisfaction: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'.
# 18. MaritalStatus: Married, Single, Divorced.
# 19. MonthlyIncome: Employees' numeric monthly income.
# 20. Monthly Rate
# 21. NumCompaniesWorked: Number of companies they worked for before joinging IBM.
# 22. Over 18 years old
# 23. Over Time
# 24. Percent Salary Hike
# 25. PerformanceRating: 1 'Low' 2 'Good' 3 'Excellent' 4 'Outstanding'.
# 26. RelationshipSatisfaction: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'.
# 27. Standard Hours
# 28. Stokck Option Level
# 29. Total Working Years
# 30. Training Times Last Year
# 31. WorkLifeBalance: 1 'Bad' 2 'Good' 3 'Better' 4 'Best'.
# 32. YearsAtCompany: Years they worked for IBM.
# 33. Years Current Role
# 34. Years Since Last Promotion
# 35. Years with Current Manager

# %% [markdown]
# We have 35 variabels in this database.

# %% [markdown]
# # 2. Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
#supressing all the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("/users/arissa/Desktop/IBM_Attrition.xlsx")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# We have 35 variabels in this database and 1470 employees' information in this dataset.

# %%
# check missing values
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There is no missing valeus. Perfect!

# %% [markdown]
# # 3. Exploratory Data Analysis

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# recode
df["turnover"] = np.where(df["Attrition"] == "Yes",1,0)

# %%
mycolors = ["pink", "lightblue"]
ax=(df["Attrition"].value_counts()/df.shape[0]).plot(kind='pie',label='',autopct='%1.1f%%', colors=mycolors,figsize=(10,6))
ax.set_title("Employee Attrition in the Company", size=20);

# %% [markdown]
# * Approximately 16% of employees will leave the company based on the historical data record.

# %% [markdown]
# ## 3.1 Explore the Relationship between Turnover and Other Variables

# %%
#  plotting the distribution of numerical variables and its effect on attrition

# %%
def NumericalVariables_targetPlots(df,segment_by,target_var = "Attrition"):
    """A function for plotting the distribution of numerical variables and its effect on attrition"""
    
    fig, ax = plt.subplots(ncols= 2, figsize = (14,6))    

    #boxplot for comparison
    sns.boxplot(x = target_var, y = segment_by, data=df, ax=ax[0], palette='Greens_r')

    ax[0].set_title("Comparision of " + segment_by + " vs " + target_var)
    #distribution plot
    ax[1].set_title("Distribution of "+segment_by)
    ax[1].set_ylabel("Count")
    sns.histplot(data = df[segment_by], stat='count', color='cyan')

    plt.show()

# %%
def CategoricalVariables_targetPlots(df, segment_by,invert_axis = False, target_var = "turnover"):
    
    """A function for Plotting the effect of variables(categorical data) on attrition """
    
    fig, ax = plt.subplots(ncols= 2, figsize = (14,6))
    
    #countplot for distribution along with target variable
    #invert axis variable helps to inter change the axis so that names of categories doesn't overlap
    if invert_axis == False:
        sns.countplot(x = segment_by, data=df,hue="Attrition",ax=ax[0], palette='PuRd')
    else:
        sns.countplot(y = segment_by, data=df,hue="Attrition",ax=ax[0],palette='PuRd')
        
    ax[0].set_title("Comparision of " + segment_by + " vs " + "Turnover")
    
    #plot the effect of variable on attrition
    if invert_axis == False:
        sns.barplot(x = segment_by, y = target_var ,data=df,ci=None,palette='autumn')
    else:
        sns.barplot(y = segment_by, x = target_var ,data=df,ci=None,palette='autumn')
        
    ax[1].set_title("Attrition rate by {}".format(segment_by))
    ax[1].set_ylabel("Turnover Rate")
    plt.tight_layout()

    plt.show()

# %% [markdown]
# ### 3.1.1 Turnover vs. Age

# %%
NumericalVariables_targetPlots(df,segment_by="Age")

# %% [markdown]
# * We found that the majority of employees in the company are between 30 and 40 Yrs. Minimum age is 18 Yrs and Maximum age is 60 Yrs.
#
# * From the Age Comparision boxplot, majority of people who left the company are below 40 Yrs and among the people who didn't left the company are of age 32 to 40 years
#
# * Younger employees are more likely to leave the company.

# %% [markdown]
# ### 3.1.2 Turnover vs. Daily Rate

# %%
NumericalVariables_targetPlots(df,"DailyRate")

# %% [markdown]
# Minimun daily rate in the company is 102, and the maximun daily rate is 1499. The distribution of daily rate is quite even.
#
# The average of daily rate is around 802. We find that employees who have lower daily rate might be more likely to leave the company. Then let's take a look at monthly rate.

# %%
NumericalVariables_targetPlots(df,"MonthlyIncome")

# %% [markdown]
# At this time, it is more obvious that for employees who left the company tend to have lower monthly income compared to employees
# who stay in the company. The majority of employees' monthly income is lower than 5,000.

# %% [markdown]
# ### 3.1.3 Turnover vs. Hourly Rate

# %%
NumericalVariables_targetPlots(df,"HourlyRate")

# %% [markdown]
# * From plot we have seen that there is no significant difference in the hourly rate and attrition.

# %% [markdown]
# ### 3.1.4. Turnover vs. Percent Salary Hike

# %%
NumericalVariables_targetPlots(df,"PercentSalaryHike")

# %% [markdown]
# Employees who received less salary hike are more likely to leave the company. The majority of employees' percent of salary hike is between 12% to 16%.

# %% [markdown]
# ### 3.1.5. Turnover vs. Total Working Years

# %%
NumericalVariables_targetPlots(df,"TotalWorkingYears")

# %%
sns.boxplot(data=df['TotalWorkingYears'], color='blue')
plt.title("Box Plot of Total Working Years of Employees");

# %% [markdown]
# Employees who left the company usually have shorter total working years. The box plot shows that half of the company's employees have been working for the company for 5 to 15 years. If employees who work for the company less than 10 years have a higher chance to leave, we may need to focus on retaining those employees who have contributed to the company for around 10 years.

# %% [markdown]
# ### 3.1.6. Turnover vs. Distance From Home

# %%
NumericalVariables_targetPlots(df,"DistanceFromHome")

# %% [markdown]
# Employees' home distance between the workplace also influences turnover rate. For employees whose commuting distance is more than 12 kilometres, they may be more likely to leave the company.

# %% [markdown]
# ### 3.1.7 Turnover vs. Job Involvement

# %%
CategoricalVariables_targetPlots(df,"JobInvolvement")

# %%
df['JobInvolvement'].value_counts()
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %%
pd.DataFrame(round(df['JobInvolvement'].value_counts()/df.shape[0]*100,2))
# Out:
#    JobInvolvement
# 3           59.05
# 2           25.51
# 4            9.80
# 1            5.65

# %% [markdown]
# * The majority of (59%) the company's employees have high job involvement. Only 9.8% of employees have **very high** job involvement. Maybe the company should increase employees' job involvement because we can see that employees who have very high job involvement also have the lowest turnover rate.
#
# * Around 33% of low job involvement employees will leave the company.
# So how can we increase employees' job involvement, and make them feel important and contribute more to the company?

# %% [markdown]
# ### 3.1.8 Turnover vs. Job Satisfication

# %%
CategoricalVariables_targetPlots(df,"JobSatisfaction")

# %%
pd.DataFrame(round(df['JobSatisfaction'].value_counts()/df.shape[0]*100,2))
# Out:
#    JobSatisfaction
# 4            31.22
# 3            30.07
# 1            19.66
# 2            19.05

# %% [markdown]
# * We can see that most employees (60%) have high or very high job satisfaction. 23% of employees who have low job satisfaction chose to leave, and 16% of employees who chose level2 and level 3 satisfaction levels will also leave. Maybe we should explore why employees who have high job satisfaction also quit the company.

# %% [markdown]
# ### 3.1.9 Turnover vs. Performance Rating

# %%
CategoricalVariables_targetPlots(df,"PerformanceRating")

# %% [markdown]
# * We can see that all of the employees' performance is rated as " excellent" and "outstanding". There is no significant difference between the performance rating and turnover rate.

# %% [markdown]
# ### 3.1.10. Turnover vs. Relationship Satisfaction

# %%
CategoricalVariables_targetPlots(df,"RelationshipSatisfaction")

# %% [markdown]
# * Even though employees think they have high or very high relationship satisfaction, 15% of them will leave the company. Maybe this is not the determinant factor which makes people leave.

# %% [markdown]
# ### 3.1.11. Turnover vs. Work Life Balance

# %%
CategoricalVariables_targetPlots(df,"WorkLifeBalance")

# %% [markdown]
# * 30% of the employees who rated as Bad WorkLifeBalance have left the company. This figure is also the highest among four categories.
# * In order to retain more talent, improving work life balance for employees is definitely an important method.

# %% [markdown]
# ### 3.1.12. Turnover vs.Overtime

# %%
CategoricalVariables_targetPlots(df,"OverTime")

# %% [markdown]
# * Overtime is a strong indicator of attrition. 30% of employees who work overtime chose to leave the company.

# %% [markdown]
# ### 3.1.13. Turnover vs.Overtime

# %%
CategoricalVariables_targetPlots(df,segment_by="BusinessTravel")

# %% [markdown]
# * There are more people who travel rarely compared to people who travel frequently. However, for employees who travel frequently, around 25% of them have left the company, which accounts for the highest proportion.
#
# * Maybe the company should improve employees' travel benefits, and if business travel is unavoidable for certain departments, how to increase employees' satisfaction with travel becomes an important aspect which we can improve.

# %% [markdown]
# ### 3.1.13. Turnover vs.Department

# %%
pd.DataFrame(data=round(df.Department.value_counts()/df.shape[0]*100,2))
# Out:
#                         Department
# Research & Development       65.37
# Sales                        30.34
# Human Resources               4.29

# %%
CategoricalVariables_targetPlots(df,segment_by="Department")

# %% [markdown]
# * Most of the employees (65%) are in the Research & Development Department in the company, and 30% of employees are working in the Sales department.
#
# * However, the sales department has the highest turnover rate. 20% of employees who work in the sales department will leave. Then followed by the HR department, which is around 18%. The R & D department has the lowest turnover rate.
#
# * I think the Sales department should primarily explore the reasons why it has the highest turnover rate. Then the HR department, which has only 5% of employees in the database. Nearly 19% of turnover rate for the smallest department may also cause a very large impact.

# %% [markdown]
# ### 3.1.14. Turnover vs.Education Field

# %%
pd.DataFrame(data=round(df.EducationField.value_counts()/df.shape[0]*100,2))
# Out:
#                   EducationField
# Life Sciences              41.22
# Medical                    31.56
# Marketing                  10.82
# Technical Degree            8.98
# Other                       5.58
# Human Resources             1.84

# %%
CategoricalVariables_targetPlots(df,"EducationField")

# %% [markdown]
# * Most employees (41%) have a life sciences educational background in the company, followed by the medical and marketing field.
#
# * Life sciences and Medical fields have lower turnover rate compared to other educational fields, such as HR, technical degree, and marketing.
#
# * The company has the lowest proportion of employees who have an HR background, but the turnover rate is the highest.
# Is this because the company's HR department is under-developed, and HR degree holders cannot look for a right position?
#
# * How can we retain HR, IT and Marketing talent become an important mission for the company.

# %% [markdown]
# ### 3.1.15. Turnover vs. Environment Satisfaction

# %%
CategoricalVariables_targetPlots(df,"EnvironmentSatisfaction")

# %% [markdown]
# * 25% of employees who have low environment satisfaction will leave the company.

# %% [markdown]
# ### 3.1.16. Turnover vs. Job Role

# %%
pd.DataFrame(data=round(df.JobRole.value_counts()/df.shape[0]*100,2))
# Out:
#                            JobRole
# Sales Executive              22.18
# Research Scientist           19.86
# Laboratory Technician        17.62
# Manufacturing Director        9.86
# Healthcare Representative     8.91
# Manager                       6.94
# Sales Representative          5.65
# Research Director             5.44
# Human Resources               3.54

# %%
CategoricalVariables_targetPlots(df,"JobRole", invert_axis=True)

# %% [markdown]
# * We can find that 22% of employees are Sales Executive, nearly 20% are research scientists and 18% are Laboratory Technicians.
#
# * Sales representatives have the highest turnover rate, which means 40% of sales representatives chose to leave the company. This finding is aligned with what we found before. Sales department has the highest turnover rate.
#
# * Then we can see HRs have the second highest turnover rate. 23% of them tend to quit.

# %% [markdown]
# ### 3.1.17. Turnover vs. Gender

# %%
CategoricalVariables_targetPlots(df,"Gender")

# %% [markdown]
# * Males are slightly more likely to leave the company. However, the gender difference in terms of turnover rate is not very significant.

# %% [markdown]
# ### 3.1.18. Turnover vs. Marital Status

# %%
CategoricalVariables_targetPlots(df,"MaritalStatus")

# %% [markdown]
# * We can see that employees who are single are more likely to leave. This might be because employees who get married and have family tend to be more stable than single persons.

# %% [markdown]
# ## 3.2 Further Explore Turnover Rate

# %% [markdown]
# ### 3.2.1 Why Sales and HR department have the highest turnover rate?

# %%
role_income = df.groupby('JobRole', as_index=False)[['MonthlyIncome', 'turnover']].mean().sort_values(by=['MonthlyIncome'])
role_income
# Out:
#                      JobRole  MonthlyIncome  turnover
# 8       Sales Representative    2626.000000  0.397590
# 2      Laboratory Technician    3237.169884  0.239382
# 6         Research Scientist    3239.972603  0.160959
# 1            Human Resources    4235.750000  0.230769
# 7            Sales Executive    6924.279141  0.174847
# 4     Manufacturing Director    7295.137931  0.068966
# 0  Healthcare Representative    7528.763359  0.068702
# 5          Research Director   16033.550000  0.025000
# 3                    Manager   17181.676471  0.049020

# %%
sns.factorplot(x='JobRole', y='MonthlyIncome', data=role_income, aspect=4, size=4, kind='bar',palette='PuRd', ax=ax)
sns.factorplot(x='JobRole', y='turnover', data=role_income, aspect=4, size=4,secondary_y=True, ax=ax);

# %% [markdown]
# * Sales representatives left the company maybe because of the low compensation.
# * HR employees' monthly income is even higher than laboratory technicians and research scientists, but the turnover rate is higher than the two departments. The company should explore the reasons why the HR department has a relatively high turnover rate.

# %% [markdown]
# #### We focused on the relationship between turnover and other related variables in the database.
# #### Then I want to check a correlation heatmap before building machine learning models.
# #### A correlation heatmap is a heatmap that shows a 2D correlation matrix between two discrete dimensions.

# %%
# delete "EmployeeCount" and "StandardHours" first because these two variables are constant
df=df.drop(['EmployeeCount','StandardHours'], axis=1)

# %%
f, ax = plt.subplots(figsize=(20, 20))
corr = df.corr()
sns.heatmap(corr, cmap=sns.diverging_palette(200, 10, as_cmap=True),annot = True);

# %% [markdown]
# * I do not see which factor has a very strong correlation with turnover rate.
# * Job level and total working years are highly correlated.
# * Monthly Income and total working years are highly correlated.
# * Performance rating and percentage salary hike are highly correlated.
# * Years with current manager and years at company and years at current role are highly correlated.

# %%
# I want to delete highly correlated variables, for instrance, years with current manager and years at company and years 
# in current role, I only want to remain one.
df=df.drop(['YearsInCurrentRole','YearsWithCurrManager','JobLevel'], axis=1)

# %% [markdown]
# # 4. Machine Learning Models

# %% [markdown]
# ## 4.1. Decision Tree Classification

# %% [markdown]
#
# Decision tree builds classification or regression models in the form of a tree structure. It breaks down a dataset into smaller and smaller subsets while at the same time an associated decision tree is incrementally developed. The final result is a tree with decision nodes and leaf nodes.

# %% [markdown]
# Gini Index, also known as **Gini impurity**, calculates the amount of probability of a specific feature that is classified incorrectly when selected randomly. If all the elements are linked with a single class then it can be called pure.

# %% [markdown]
# The minimum value of the Gini Index is 0. This happens when the node is pure, this means that all the contained elements in the node are of one unique class. Therefore, this node will not be split again. Thus, the optimum split is chosen by the features with less Gini Index. Moreover, it gets the maximum value when the probability of the two classes are the same.

# %% [markdown]
# ### Handling categorical variables first

# %%
df.dtypes
# Out:
# Age                          int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# ...

# %%
# don't include attition because we already have turnover rate 
# don't include "over 18" because all employees are 18+ years old 
categorical_variables=['BusinessTravel','Department','EducationField',
                      'Gender','JobRole','MaritalStatus','OverTime']

# %%
df1 = pd.get_dummies(df, columns=categorical_variables)

# %%
df1.dtypes
# Out:
# Age                                  int64
# DailyRate                            int64
# DistanceFromHome                     int64
# Education                            int64
# EmployeeNumber                       int64
# EnvironmentSatisfaction              int64
# HourlyRate                           int64
# JobInvolvement                       int64
# JobLevel                             int64
# JobSatisfaction                      int64
# MonthlyIncome                        int64
# MonthlyRate                          int64
# NumCompaniesWorked                   int64
# PercentSalaryHike                    int64
# PerformanceRating                    int64
# RelationshipSatisfaction             int64
# StockOptionLevel                     int64
# TotalWorkingYears                    int64
# TrainingTimesLastYear                int64
# WorkLifeBalance                      int64
# YearsAtCompany                       int64
# YearsInCurrentRole                   int64
# ...

# %% [markdown]
# ### Train Test Split

# %%
X=df1.drop(['turnover'], axis=1)

# %%
X.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0   41       1102                 1          2               1
# 1   49        279                 8          1               2
# 2   37       1373                 2          2               4
# 3   33       1392                 3          4               5
# 4   27        591                 2          1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Manufacturing Director  \
# 0                4  ...                               0
# 1                2  ...                               0
# ...

# %%
Y=df1['turnover']

# %%
# This is an imbalanced dataset 
Y.value_counts()
# Out:
# 0    1233
# 1     237
# Name: turnover, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,Y,test_size = 0.2,random_state = 101)

# %%
# Decision Tree Classifier
# Import Decision tree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Create a Decision tree classifier model
clf = DecisionTreeClassifier()

# Hyperparameter Optimization
parameters = {'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['entropy', 'gini'],
              'max_depth': [2, 3, 5, 10, 50], 
              'min_samples_split': [2, 3, 50, 100],
              'min_samples_leaf': [1, 5, 8, 10]
             }

# Run the grid search
grid_obj = GridSearchCV(clf, parameters)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
clf = grid_obj.best_estimator_

# Train the model using the training sets 
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=50, max_features='log2', min_samples_leaf=10,
#                        min_samples_split=3)

# %%
# Prediction on test set
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,  classification_report

confusion_matrix(y_test, y_pred)
# Out:
# array([[235,  14],
#        [ 38,   7]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90       249
#            1       0.33      0.16      0.21        45
#
#     accuracy                           0.82       294
#    macro avg       0.60      0.55      0.56       294
# weighted avg       0.78      0.82      0.80       294

# %% [markdown]
# We can see that F1 score is very low when y=1, because this dataset is imbalanced. We have too few variables which employees left the company.

# %% [markdown]
# ### Oversampling

# %% [markdown]
# Oversampling is resampling the minority class so that it equals to the majority class. I use SMOTE method to oversampling the data.

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state=101)

#Apply Over Sampling
print('Before Oversampling')
print(sorted(Counter(y_train).items()))
X_train, y_train = SMOTE().fit_resample(X_train, y_train)
print('After Oversampling')
print(sorted(Counter(y_train).items()))
# Out:
# Before Oversampling
# [(0, 984), (1, 192)]
# After Oversampling
# [(0, 984), (1, 984)]

# %%
### Fit Decision Tree model again
clf = DecisionTreeClassifier()

# Hyperparameter Optimization
parameters = {'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['entropy', 'gini'],
              'max_depth': [2, 3, 5, 10, 50], 
              'min_samples_split': [2, 3, 50, 100],
              'min_samples_leaf': [1, 5, 8, 10]
             }

# Run the grid search
grid_obj = GridSearchCV(clf, parameters)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
clf = grid_obj.best_estimator_

# Train the model using the training sets 
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[198,  51],
#        [ 34,  11]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82       249
#            1       0.18      0.24      0.21        45
#
#     accuracy                           0.71       294
#    macro avg       0.52      0.52      0.51       294
# weighted avg       0.75      0.71      0.73       294

# %% [markdown]
# We find that f1-score, recall and precision all increase in terms of y=1. Over sampling can help us better predict employee turnover.

# %%
# Finding the variable with more importance
feature_imp = pd.Series(clf.feature_importances_,index= X_train.columns).sort_values(ascending=False)
# Creating a bar plot
feature_imp=feature_imp[0:10,]
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to the graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()

# %% [markdown]
# ### Undersampling

# %% [markdown]
# Undersampling is resampling the majority class so that it equals to the minority class. By using the Random Under Sampler, the data is cut randomly.

# %%
from imblearn.under_sampling import RandomUnderSampler
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=101)
print('Before Oversampling')
print(sorted(Counter(y_train).items()))
#Apply Random Under Sampling
under = RandomUnderSampler(random_state=0)
X_train, y_train =under.fit_resample(X_train, y_train)
print('After Oversampling')
print(sorted(Counter(y_train).items()))
# Out:
# Before Oversampling
# [(0, 984), (1, 192)]
# After Oversampling
# [(0, 192), (1, 192)]

# %%
### Fit Decision Tree model again
clf = DecisionTreeClassifier()

# Hyperparameter Optimization
parameters = {'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['entropy', 'gini'],
              'max_depth': [2, 3, 5, 10, 50], 
              'min_samples_split': [2, 3, 50, 100],
              'min_samples_leaf': [1, 5, 8, 10]
             }

# Run the grid search
grid_obj = GridSearchCV(clf, parameters)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
clf = grid_obj.best_estimator_

# Train the model using the training sets 
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82       249
#            1       0.25      0.42      0.31        45
#
#     accuracy                           0.71       294
#    macro avg       0.56      0.59      0.57       294
# weighted avg       0.78      0.71      0.74       294

# %% [markdown]
# Undersampling also helps us better predict employee turnover. Although accuracy rate slightly decreases, F1 score is the metric we pay more attention to.

# %% [markdown]
# ## 4.2 Gaussian Naive Bayes

# %%
# Gaussian Naive Bayes

# Import library of Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB
X_train, X_test, y_train,y_test = train_test_split(X,Y,test_size = 0.2,random_state = 101)
# Create a Gaussian Classifier
model = GaussianNB()
# Train the model using the training sets 
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[196  53]
#  [ 17  28]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85       249
#            1       0.35      0.62      0.44        45
#
#     accuracy                           0.76       294
#    macro avg       0.63      0.70      0.65       294
# weighted avg       0.83      0.76      0.79       294

# %% [markdown]
# Naive Bayes Model performs very well because we have the highest f1-score in this model.

# %% [markdown]
# ## 4.3 Random Forest Classifier

# %%
# Import library of RandomForestClassifier model
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest Classifier
rf = RandomForestClassifier()

# Hyperparameter Optimization
parameters = {'n_estimators': [4, 6, 9, 10, 15], 
              'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['entropy', 'gini'],
              'max_depth': [2, 3, 5, 10], 
              'min_samples_split': [2, 3, 5],
              'min_samples_leaf': [1, 5, 8]
             }

# Run the grid search
grid_obj = GridSearchCV(rf, parameters)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the rf to the best combination of parameters
rf = grid_obj.best_estimator_

# Train the model using the training sets 
rf.fit(X_train,y_train)

y_pred = rf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[244   5]
#  [ 35  10]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       249
#            1       0.67      0.22      0.33        45
#
#     accuracy                           0.86       294
#    macro avg       0.77      0.60      0.63       294
# weighted avg       0.84      0.86      0.83       294

# %%
# Finding the variable with more importance
feature_imp = pd.Series(rf.feature_importances_,index= X_train.columns).sort_values(ascending=False)
# Creating a bar plot
feature_imp=feature_imp[0:10,]
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to the graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()

# %% [markdown]
# ## 4.4 Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=101)

# Create a Logistic regression classifier
logreg = LogisticRegression()

# Train the model using the training sets 
logreg.fit(X_train, y_train)
Y_pred = logreg.predict(X_test)
confusion_matrix(y_test, Y_pred)
print(classification_report(y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       249
#            1       0.75      0.07      0.12        45
#
#     accuracy                           0.85       294
#    macro avg       0.80      0.53      0.52       294
# weighted avg       0.84      0.85      0.80       294

# %%
#Apply Over Sampling
print('Before Oversampling')
print(sorted(Counter(y_train).items()))
X_train, y_train = SMOTE().fit_resample(X_train, y_train)
print('After Oversampling')
print(sorted(Counter(y_train).items()))
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
Y_pred = logreg.predict(X_test)
print(confusion_matrix(y_test, Y_pred))
print(classification_report(y_test, Y_pred))
# Out:
# Before Oversampling
# [(0, 984), (1, 192)]
# After Oversampling
# [(0, 984), (1, 984)]
# [[155  94]
#  [ 25  20]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.62      0.72       249
#            1       0.18      0.44      0.25        45
#
#     accuracy                           0.60       294
#    macro avg       0.52      0.53      0.49       294
# weighted avg       0.76      0.60      0.65       294

# %%
#Apply Random Under Sampling

from imblearn.under_sampling import RandomUnderSampler
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=101)
print('Before Undersampling')
print(sorted(Counter(y_train).items()))
under = RandomUnderSampler(random_state=0)
X_train, y_train =under.fit_resample(X_train, y_train)
print('After OUnderampling')
print(sorted(Counter(y_train).items()))
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
Y_pred = logreg.predict(X_test)
print(confusion_matrix(y_test, Y_pred))
print(classification_report(y_test, Y_pred))
# Out:
# Before Undersampling
# [(0, 984), (1, 192)]
# After OUnderampling
# [(0, 192), (1, 192)]
# [[143 106]
#  [ 25  20]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.57      0.69       249
#            1       0.16      0.44      0.23        45
#
#     accuracy                           0.55       294
#    macro avg       0.50      0.51      0.46       294
# weighted avg       0.75      0.55      0.62       294

# %% [markdown]
# # 3. Conclusion

# %% [markdown]
# 1. Since we want to use machine learning algorithms to predict which employees are more likely to leave the company, we focus on F1 score rather than accuracy. When the dataset is imalanced, True Positive can be very high but True Negative is very low. Accuracy cannot reflect this difference. However, F1 score provides a better picture of incorrectly classified cases.

# %% [markdown]
# 2. We find that the Naive Bayes Model performs very well when it is predicting which employers are more likely to leave. We want to identify which model  has the highest True Negative value because when y=1, it means the employee left the company.

# %% [markdown]
# 3. I applied oversampling and undersampling methods when I use decision tree modelling and logistic regression models. Sometimes the oversampling method performs better than undersamping. However, Naive Bayes still stands out compared to other algorithms even after conducting resampling.
